# %% [markdown]
# ## Objective of this project is to extract data of coronavirus from worldometer by using webscraping and stored in Mysql workbench database

# %%
# Importing Libraries
import mysql.connector
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Connecting Mysql workbench with jupyter notebook
xyz = mysql.connector.connect(host = 'localhost',user = 'root', password = 'Suman@1289', database = 'ISHU')

# %%
myname = xyz.cursor()

# %%
# Creating table to store data in database
myname.execute("CREATE TABLE CoronaPatient_Worldwide(DAY INT(2) NOT NULL AUTO_INCREMENT,REGION VARCHAR(20),TOTAL_CASES VARCHAR(20),NEW_CASES VARCHAR(20),TOTAL_DEATHS VARCHAR(20),NEW_DEATHS VARCHAR(20),TOTAL_RECOVERED VARCHAR(20),ACTIVE_CASES VARCHAR(20),SERIOUS VARCHAR(20),PRIMARY KEY (DAY))")

# %%
url = "https://www.worldometers.info/coronavirus/"

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content,'html.parser')

# %%
rows = soup.find_all('tr')

# %%
print(rows)
# Out:
# [<tr>
# <th width="100">Country,<br>Other</br></th>
# <th width="20">Total<br>Cases</br></th>
# <th width="30">New<br>Cases</br></th>
# <th width="30">Total<br>Deaths</br></th>
# <th width="30">New<br>Deaths</br></th>
# <th width="30">Total<br>Recovered</br></th>
# <th width="30">Active<br>Cases</br></th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th style="display:none" width="30">Continent</th>
# </tr>, <tr class="total_row_world row_continent" data-continent="North America" style="display: none">
# <td style="text-align:left;">
# <nobr>North America</nobr>
# </td>
# <td>1,495,849</td>
# <td>+23,468</td>
# <td>89,954</td>
# <td>+1,103</td>
# <td>320,040</td>
# <td>1,085,855</td>
# <td>17,659</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# ...

# %%
s = soup.find_all('div',class_="main_table_countries_today")

# %%
b =  soup.find_all('tr',class_="total_row_world")

# %%
print(b[7:8])
# Out:
# [<tr class="total_row_world">
# <td style="text-align:left;">World</td>
# <td>4,176,887</td>
# <td>+78,608</td>
# <td>283,678</td>
# <td>+3,454</td>
# <td>1,487,454</td>
# <td>2,405,755</td>
# <td>47,016</td>
# <td>536</td>
# <td>36.4</td>
# <td></td>
# <td></td>
# <td data-continent="all" style="display:none">All</td>
# </tr>]

# %%
for row in b[7:8]:
    cols = row.find_all('td')
    cols = [x.text.strip() for x in cols]
    print(cols)
# Out:
# ['World', '4,176,887', '+78,608', '283,678', '+3,454', '1,487,454', '2,405,755', '47,016', '536', '36.4', '', '', 'All']

# %%
cols[0]
# Out:
# 'World'

# %%
cols[1]
# Out:
# '4,176,887'

# %%
Region = cols[0]
Total_Cases = cols[1]
New_Cases = cols[2]
Total_Deaths = cols[3]
New_Deaths = cols[4]
Total_Recovered = cols[5]
Active_Cases = cols[6]
Serious = cols[7]

# %%
# Insering data in table of database
sql = "INSERT INTO CoronaPatient_Worldwide(REGION,TOTAL_CASES,NEW_CASES,TOTAL_DEATHS,NEW_DEATHS,TOTAL_RECOVERED,ACTIVE_CASES,SERIOUS) VALUES(%s,%s,%s,%s,%s,%s,%s,%s)"

# %%
myname.execute(sql,(Region,Total_Cases,New_Cases,Total_Deaths,New_Deaths,Total_Recovered,Active_Cases,Serious))

# %%
xyz.commit()

# %%
# Information stored in database
myname.execute("SELECT * FROM CoronaPatient_Worldwide")
myresult = myname.fetchall()
for y in myresult:
    print(y)
# Out:
# (1, 'World', '1,418,730', '+72,726', '81,497', '+6,843', '301,398', '1,035,835', '47,925')
# (2, 'World', '1,432,084', '+1,165', '82,099', '+65', '302,209', '1,047,776', '47,895')
# (3, 'World', '1,433,055', '+2,136', '82,138', '+104', '302,367', '1,048,550', '47,931')
# (4, 'World', '1,444,822', '+13,903', '83,103', '+1,069', '309,110', '1,052,609', '47,980')
# (5, 'World', '1,468,842', '+37,923', '85,445', '+3,411', '316,482', '1,066,915', '47,975')
# (6, 'World', '1,513,243', '+82,262', '88,403', '+6,367', '329,731', '1,095,109', '48,078')
# (7, 'World', '1,518,773', '+813', '88,505', '+50', '330,589', '1,099,679', '48,079')
# (8, 'World', '1,538,486', '+20,526', '89,975', '+1,520', '340,521', '1,107,990', '48,512')
# (9, 'World', '1,577,747', '+59,787', '93,673', '+5,218', '348,276', '1,135,798', '48,934')
# (10, 'World', '1,604,718', '+1,066', '95,735', '+42', '356,660', '1,152,323', '49,128')
# ...

# %%
df = pd.DataFrame(myresult,columns = ['Day','Region','Total_cases','New_cases','Total_Deaths','New_Deaths','Total_recovered','Active_cases','Serious'])
df
# Out:
#     Day Region Total_cases New_cases Total_Deaths New_Deaths Total_recovered  \
# 0     1  World   1,418,730   +72,726       81,497     +6,843         301,398
# 1     2  World   1,432,084    +1,165       82,099        +65         302,209
# 2     3  World   1,433,055    +2,136       82,138       +104         302,367
# 3     4  World   1,444,822   +13,903       83,103     +1,069         309,110
# 4     5  World   1,468,842   +37,923       85,445     +3,411         316,482
# ..  ...    ...         ...       ...          ...        ...             ...
# 67   68  World   3,719,899   +76,628      257,747     +5,506       1,235,817
# 68   69  World   3,719,899   +76,628      257,747     +5,506       1,235,817
# 69   70  World   3,812,513   +87,995      264,109     +6,083       1,288,726
# 70   71  World   3,912,301   +94,919      270,348     +5,511       1,340,553
# 71   72  World   4,176,887   +78,608      283,678     +3,454       1,487,454
#
#    Active_cases Serious
# ...

# %%
# Final data about coronavirus
df1 = df.drop(['Day','Region'],axis = 1)

# %%
df1
# Out:
#    Total_cases New_cases Total_Deaths New_Deaths Total_recovered Active_cases  \
# 0    1,418,730   +72,726       81,497     +6,843         301,398    1,035,835
# 1    1,432,084    +1,165       82,099        +65         302,209    1,047,776
# 2    1,433,055    +2,136       82,138       +104         302,367    1,048,550
# 3    1,444,822   +13,903       83,103     +1,069         309,110    1,052,609
# 4    1,468,842   +37,923       85,445     +3,411         316,482    1,066,915
# ..         ...       ...          ...        ...             ...          ...
# 67   3,719,899   +76,628      257,747     +5,506       1,235,817    2,226,335
# 68   3,719,899   +76,628      257,747     +5,506       1,235,817    2,226,335
# 69   3,812,513   +87,995      264,109     +6,083       1,288,726    2,259,678
# 70   3,912,301   +94,919      270,348     +5,511       1,340,553    2,301,400
# 71   4,176,887   +78,608      283,678     +3,454       1,487,454    2,405,755
#
#    Serious
# 0   47,925
# ...
